# %% [markdown]
# ### 9 pebbles
# One pebble in center: 8 pebbles for each corner

# %%
# Nine 3cm pebbles
# Side-length: 2*3.4641016151

##########
# import #
##########
import gmsh
import sys

######################
# Create Sphere Mesh #
######################
# Initialize the gmsh API
gmsh.initialize()
# Create a new model "9pebs"
gmsh.model.add("9pebs")

# Define radius of sphere and side length of bounding box
sphere_radius = 3.0 #cm
half_length = 3.5921476745623537 # Updated for PF = 0.61 #3.4641016151 # cm
side_length = half_length*2

# Creates a sphere centered at (0,0,0) with given radius
p_1 = gmsh.model.occ.addSphere(-half_length,  half_length,  half_length, sphere_radius)
p_2 = gmsh.model.occ.addSphere( half_length,  half_length,  half_length, sphere_radius)
p_3 = gmsh.model.occ.addSphere( half_length, -half_length,  half_length, sphere_radius)
p_4 = gmsh.model.occ.addSphere(-half_length, -half_length,  half_length, sphere_radius)
p_5 = gmsh.model.occ.addSphere( 0,            0,            0,           sphere_radius)
p_6 = gmsh.model.occ.addSphere(-half_length,  half_length, -half_length, sphere_radius)
p_7 = gmsh.model.occ.addSphere( half_length,  half_length, -half_length, sphere_radius)
p_8 = gmsh.model.occ.addSphere( half_length, -half_length, -half_length, sphere_radius)
p_9 = gmsh.model.occ.addSphere(-half_length, -half_length, -half_length, sphere_radius)

# creates the bounding box.
bound_box = gmsh.model.occ.addBox(-half_length, -half_length, -half_length, side_length, side_length, side_length) # addBox(x, y, z, dx, dy, dz, tag=-1)


# gmsh.model.occ.cut(objectDimTags, toolDimTags, tag=-1, removeObject=True, removeTool=True)
# The function "cut" subtracts one volume from another volume.
# In this case, we are cutting the pebble sphere from the bounding box.
# objectDimTags: The entities to be cut. Each pair (dimension, tag) specifies an object
# toolDimTags: The cutting tools that remove material from objectDimTags.
# removeTool: boolean -> if set to True, removes the cutting tools: We don't want this because we want to mesh the pebble sphere also.
intersect_peb_1 = gmsh.model.occ.intersect([(3, p_1)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_1       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_1)], removeTool=False)

intersect_peb_2 = gmsh.model.occ.intersect([(3, p_2)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_2       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_2)], removeTool=False)

intersect_peb_3 = gmsh.model.occ.intersect([(3, p_3)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_3       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_3)], removeTool=False)

intersect_peb_4 = gmsh.model.occ.intersect([(3, p_4)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_4       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_4)], removeTool=False)

intersect_peb_5 = gmsh.model.occ.intersect([(3, p_5)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_5       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_5)], removeTool=False)

intersect_peb_6 = gmsh.model.occ.intersect([(3, p_6)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_6       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_6)], removeTool=False)

intersect_peb_7 = gmsh.model.occ.intersect([(3, p_7)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_7       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_7)], removeTool=False)

intersect_peb_8 = gmsh.model.occ.intersect([(3, p_8)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_8       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_8)], removeTool=False)

intersect_peb_9 = gmsh.model.occ.intersect([(3, p_9)], [(3, bound_box)], removeObject=True, removeTool=False)
cut_box_9       = gmsh.model.occ.cut([(3, bound_box)], [(3, p_9)], removeTool=False)



# Synchronize the CAD kernel with the Gmsh model
# ChatGPT says: 
#    "When working with OpenCASCADE(OCC)-based functions (gmsh.model.occ.*), changes happen only within the OCC kernel, 
#    and Gmsh doesn't immediately "see" them. Calling gmsh.model.occ.synchronize() commits these changes to the Gmsh model."
gmsh.model.occ.synchronize()

# Define Surfaces!
# Get all 2D surfaces (faces)
surfaces = gmsh.model.getEntities(2)
# Determine the bounding surfaces of the cube based on location
tol = 1e-6
xmin = ymin = zmin = -half_length - tol
xmax = ymax = zmax =  half_length + tol

outer_surfaces = []

for (dim, tag) in surfaces:
    com = gmsh.model.occ.getCenterOfMass(dim, tag)
    x, y, z = com
    if (abs(x - xmin) < tol or abs(x - xmax) < tol or
        abs(y - ymin) < tol or abs(y - ymax) < tol or
        abs(z - zmin) < tol or abs(z - zmax) < tol):
        outer_surfaces.append(tag)

# Create a single physical group for all outer surfaces
gmsh.model.addPhysicalGroup(2, outer_surfaces, tag=100)
gmsh.model.setPhysicalName(2, 100, "outer_boundary")


# Identify the volumes: we expect two volumes
volEntities = gmsh.model.getEntities(3) # dim=3 specifies that we're looking for volumes (not polygons I suppose)
print("Volumes:", volEntities)

# Define physical groups
gmsh.model.addPhysicalGroup(3, [p_1],       tag=1) # We specify "physical groups" (I think) to identify regions where we can assign properties to regions (i.e. Multi-group cross sections)
gmsh.model.setPhysicalName(3, 1, "p_1")            # An integer ID is not enough, we want to assign a name to this region.
gmsh.model.addPhysicalGroup(3, [p_2],       tag=2) 
gmsh.model.setPhysicalName(3, 2, "p_2")                
gmsh.model.addPhysicalGroup(3, [p_3],       tag=3) 
gmsh.model.setPhysicalName(3, 3, "p_3")               
gmsh.model.addPhysicalGroup(3, [p_4],       tag=4) 
gmsh.model.setPhysicalName(3, 4, "p_4")               
gmsh.model.addPhysicalGroup(3, [p_5],       tag=5) 
gmsh.model.setPhysicalName(3, 5, "p_5")               
gmsh.model.addPhysicalGroup(3, [p_6],       tag=6) 
gmsh.model.setPhysicalName(3, 6, "p_6")               
gmsh.model.addPhysicalGroup(3, [p_7],       tag=7) 
gmsh.model.setPhysicalName(3, 7, "p_7")               
gmsh.model.addPhysicalGroup(3, [p_8],       tag=8) 
gmsh.model.setPhysicalName(3, 8, "p_8")               
gmsh.model.addPhysicalGroup(3, [p_9],       tag=9) 
gmsh.model.setPhysicalName(3, 9, "p_9")               
gmsh.model.addPhysicalGroup(3, [bound_box], tag=10) # Material ID: 6
gmsh.model.setPhysicalName(3, 10, "gap")            # Region name: "gap"

# Create a MathEval field to control the mesh size.
fieldTag = gmsh.model.mesh.field.add("MathEval") # ChatGPT -> "Fields in Gmsh are used to control the size, distribution, and behavior of the mesh"
gmsh.model.mesh.field.setString(fieldTag, "F", "1.0")


# Use this field as the background mesh field.
gmsh.model.mesh.field.setAsBackgroundMesh(fieldTag) # Mesh field applied to the entire geometry

# Generate the 3D mesh
gmsh.model.mesh.generate(3)

# Save mesh in VTK format
gmsh.write("msh_meshes/9_peb.msh")
gmsh.write("vtk_meshes/9_peb.vtk")

if "-nopopup" not in sys.argv:
    gmsh.fltk.run()

gmsh.finalize()
# Out:
# Volumes: [(3, 1), (3, 2), (3, 3), (3, 4), (3, 5), (3, 6), (3, 7), (3, 8), (3, 9), (3, 10)]
# Info    : Meshing 1D...
# Info    : [ 10%] Meshing curve 14 (Circle)
# Info    : [ 10%] Meshing curve 40 (Circle)
# Info    : [ 10%] Meshing curve 42 (Circle)
# Info    : [ 10%] Meshing curve 43 (Circle)
# Info    : [ 10%] Meshing curve 44 (Line)
# Info    : [ 20%] Meshing curve 45 (Line)
# Info    : [ 20%] Meshing curve 46 (Line)
# Info    : [ 20%] Meshing curve 59 (Circle)
# Info    : [ 20%] Meshing curve 60 (Circle)
# Info    : [ 20%] Meshing curve 61 (Circle)
# Info    : [ 20%] Meshing curve 63 (Line)
# Info    : [ 30%] Meshing curve 64 (Line)
# Info    : [ 30%] Meshing curve 65 (Line)
# Info    : [ 30%] Meshing curve 78 (Circle)
# Info    : [ 30%] Meshing curve 79 (Circle)
# Info    : [ 30%] Meshing curve 80 (Circle)
# Info    : [ 30%] Meshing curve 82 (Line)
# Info    : [ 40%] Meshing curve 83 (Line)
# Info    : [ 40%] Meshing curve 84 (Line)
# Info    : [ 40%] Meshing curve 97 (Circle)
# Info    : [ 40%] Meshing curve 98 (Circle)
# Info    : [ 40%] Meshing curve 100 (Circle)
# Info    : [ 40%] Meshing curve 101 (Line)
# Info    : [ 50%] Meshing curve 102 (Line)
# Info    : [ 50%] Meshing curve 103 (Line)
# Info    : [ 50%] Meshing curve 116 (Circle)
# Info    : [ 50%] Meshing curve 117 (Circle)
# Info    : [ 50%] Meshing curve 118 (Circle)
# Info    : [ 50%] Meshing curve 120 (Line)
# Info    : [ 60%] Meshing curve 121 (Line)
# Info    : [ 60%] Meshing curve 122 (Line)
# Info    : [ 60%] Meshing curve 135 (Circle)
# Info    : [ 60%] Meshing curve 136 (Circle)
# Info    : [ 60%] Meshing curve 137 (Circle)
# Info    : [ 60%] Meshing curve 139 (Line)
# Info    : [ 70%] Meshing curve 140 (Line)
# Info    : [ 70%] Meshing curve 141 (Line)
# Info    : [ 70%] Meshing curve 154 (Circle)
# Info    : [ 70%] Meshing curve 155 (Circle)
# Info    : [ 70%] Meshing curve 156 (Circle)
# Info    : [ 70%] Meshing curve 158 (Line)
# Info    : [ 80%] Meshing curve 159 (Line)
# Info    : [ 80%] Meshing curve 160 (Line)
# Info    : [ 80%] Meshing curve 173 (Circle)
# Info    : [ 80%] Meshing curve 174 (Circle)
# Info    : [ 80%] Meshing curve 175 (Circle)
# Info    : [ 80%] Meshing curve 177 (Line)
# Info    : [ 90%] Meshing curve 178 (Line)
# Info    : [ 90%] Meshing curve 179 (Line)
# Info    : [ 90%] Meshing curve 180 (Line)
# Info    : [ 90%] Meshing curve 181 (Line)
# Info    : [ 90%] Meshing curve 182 (Line)
# Info    : [ 90%] Meshing curve 183 (Line)
# Info    : [ 90%] Meshing curve 184 (Line)
# Info    : [100%] Meshing curve 185 (Line)
# Info    : [100%] Meshing curve 186 (Line)
# Info    : [100%] Meshing curve 187 (Line)
# Info    : [100%] Meshing curve 188 (Line)
# Info    : [100%] Meshing curve 189 (Line)
# Info    : [100%] Meshing curve 190 (Line)
# Info    : [100%] Meshing curve 191 (Line)
# Info    : Done meshing 1D (Wall 0.00986587s, CPU 0.009547s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 5 (Sphere, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 16 (Sphere, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 26 (Sphere, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 29 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 36 (Sphere, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 38 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 46 (Sphere, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 47 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 48 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 49 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 56 (Sphere, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 57 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 58 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 59 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 66 (Sphere, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 67 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 68 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 69 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 76 (Sphere, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 77 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 78 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 79 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 86 (Sphere, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 87 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 88 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 89 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 90 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 91 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 92 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 93 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 94 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 95 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0528853s, CPU 0.053003s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 10 volumes with 1 connected component
# Info    : Tetrahedrizing 800 nodes...
# Info    : Done tetrahedrizing 808 nodes (Wall 0.00686339s, CPU 0.006449s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0164832s, CPU 0.014706s)
# Info    : Found volume 5
# Info    : Found volume 10
# Info    : Found volume 1
# Info    : Found volume 2
# Info    : Found volume 4
# Info    : Found volume 3
# Info    : Found volume 6
# Info    : Found volume 7
# Info    : Found volume 8
# Info    : Found volume 9
# Info    : It. 0 - 0 nodes created - worst tet radius 3.57505 (nodes removed 0 0)
# Info    : 3D refinement terminated (845 nodes total):
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 1 nodes could not be inserted
# Info    :  - 3516 tetrahedra created in 0.00345624 sec. (1017288 tets/s)
# Info    : Done meshing 3D (Wall 0.03856s, CPU 0.036096s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 13.6797) with worst = 0.0435143 / average = 0.755978:
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        23 elements
# Info    : 0.70 < quality < 0.80 :        52 elements
# Info    : 0.80 < quality < 0.90 :        31 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : 4 edge swaps, 0 node relocations (volume = 13.6797): worst = 0.569653 / average = 0.77945 (Wall 8.1841e-05s, CPU 0.000105s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        22 elements
# Info    : 0.70 < quality < 0.80 :        52 elements
# Info    : 0.80 < quality < 0.90 :        32 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 13.6781) with worst = 0.0555913 / average = 0.762472:
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        20 elements
# Info    : 0.70 < quality < 0.80 :        52 elements
# Info    : 0.80 < quality < 0.90 :        35 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : 3 edge swaps, 0 node relocations (volume = 13.6781): worst = 0.527942 / average = 0.780088 (Wall 9.7305e-05s, CPU 0.000111s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        18 elements
# Info    : 0.70 < quality < 0.80 :        54 elements
# Info    : 0.80 < quality < 0.90 :        35 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 13.6928) with worst = 0.196187 / average = 0.763788:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        27 elements
# Info    : 0.70 < quality < 0.80 :        51 elements
# Info    : 0.80 < quality < 0.90 :        33 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 13.6928): worst = 0.315924 / average = 0.764203 (Wall 4.2622e-05s, CPU 5.7e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        27 elements
# Info    : 0.70 < quality < 0.80 :        52 elements
# Info    : 0.80 < quality < 0.90 :        33 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 13.6928) with worst = 0.213054 / average = 0.763725:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        27 elements
# Info    : 0.70 < quality < 0.80 :        51 elements
# Info    : 0.80 < quality < 0.90 :        33 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 13.6928): worst = 0.315924 / average = 0.764091 (Wall 4.1306e-05s, CPU 5.5e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        27 elements
# Info    : 0.70 < quality < 0.80 :        52 elements
# Info    : 0.80 < quality < 0.90 :        33 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 109.175) with worst = 0.0826662 / average = 0.728682:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         3 elements
# Info    : 0.20 < quality < 0.30 :        12 elements
# Info    : 0.30 < quality < 0.40 :        10 elements
# Info    : 0.40 < quality < 0.50 :        20 elements
# Info    : 0.50 < quality < 0.60 :        40 elements
# Info    : 0.60 < quality < 0.70 :       133 elements
# Info    : 0.70 < quality < 0.80 :       218 elements
# Info    : 0.80 < quality < 0.90 :       177 elements
# Info    : 0.90 < quality < 1.00 :        38 elements
# Info    : 16 edge swaps, 0 node relocations (volume = 109.175): worst = 0.307981 / average = 0.744965 (Wall 0.000240412s, CPU 0.000253s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         9 elements
# Info    : 0.40 < quality < 0.50 :        15 elements
# Info    : 0.50 < quality < 0.60 :        37 elements
# Info    : 0.60 < quality < 0.70 :       140 elements
# Info    : 0.70 < quality < 0.80 :       219 elements
# Info    : 0.80 < quality < 0.90 :       178 elements
# Info    : 0.90 < quality < 1.00 :        38 elements
# Info    : Optimizing volume 6
# Info    : Optimization starts (volume = 13.6785) with worst = 0.0440853 / average = 0.743828:
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         5 elements
# Info    : 0.60 < quality < 0.70 :        22 elements
# Info    : 0.70 < quality < 0.80 :        50 elements
# Info    : 0.80 < quality < 0.90 :        29 elements
# Info    : 0.90 < quality < 1.00 :        15 elements
# Info    : 4 edge swaps, 0 node relocations (volume = 13.6785): worst = 0.240644 / average = 0.766174 (Wall 0.000114599s, CPU 0.000129s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         4 elements
# Info    : 0.60 < quality < 0.70 :        21 elements
# Info    : 0.70 < quality < 0.80 :        52 elements
# Info    : 0.80 < quality < 0.90 :        29 elements
# Info    : 0.90 < quality < 1.00 :        15 elements
# Info    : Optimizing volume 7
# Info    : Optimization starts (volume = 13.6889) with worst = 0.137705 / average = 0.757659:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         2 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :        30 elements
# Info    : 0.70 < quality < 0.80 :        50 elements
# Info    : 0.80 < quality < 0.90 :        32 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : 3 edge swaps, 0 node relocations (volume = 13.6889): worst = 0.577879 / average = 0.767897 (Wall 8.6809e-05s, CPU 8.6e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :        32 elements
# Info    : 0.70 < quality < 0.80 :        50 elements
# Info    : 0.80 < quality < 0.90 :        32 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : Optimizing volume 8
# Info    : Optimization starts (volume = 13.6889) with worst = 0.137705 / average = 0.718026:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         7 elements
# Info    : 0.50 < quality < 0.60 :        29 elements
# Info    : 0.60 < quality < 0.70 :        15 elements
# Info    : 0.70 < quality < 0.80 :        42 elements
# Info    : 0.80 < quality < 0.90 :        24 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 13.6889): worst = 0.390684 / average = 0.723448 (Wall 6.3594e-05s, CPU 6.9e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         6 elements
# Info    : 0.50 < quality < 0.60 :        30 elements
# Info    : 0.60 < quality < 0.70 :        15 elements
# Info    : 0.70 < quality < 0.80 :        42 elements
# Info    : 0.80 < quality < 0.90 :        24 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : Optimizing volume 9
# Info    : Optimization starts (volume = 13.6889) with worst = 0.137705 / average = 0.718026:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         7 elements
# Info    : 0.50 < quality < 0.60 :        29 elements
# Info    : 0.60 < quality < 0.70 :        15 elements
# Info    : 0.70 < quality < 0.80 :        42 elements
# Info    : 0.80 < quality < 0.90 :        24 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 13.6889): worst = 0.390684 / average = 0.722083 (Wall 4.1958e-05s, CPU 5.4e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         7 elements
# Info    : 0.50 < quality < 0.60 :        29 elements
# Info    : 0.60 < quality < 0.70 :        15 elements
# Info    : 0.70 < quality < 0.80 :        42 elements
# Info    : 0.80 < quality < 0.90 :        24 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : Optimizing volume 10
# Info    : Optimization starts (volume = 152.147) with worst = 0.0126257 / average = 0.749763:
# Info    : 0.00 < quality < 0.10 :         2 elements
# Info    : 0.10 < quality < 0.20 :         5 elements
# Info    : 0.20 < quality < 0.30 :        17 elements
# Info    : 0.30 < quality < 0.40 :        37 elements
# Info    : 0.40 < quality < 0.50 :        90 elements
# Info    : 0.50 < quality < 0.60 :       133 elements
# Info    : 0.60 < quality < 0.70 :       278 elements
# Info    : 0.70 < quality < 0.80 :       484 elements
# Info    : 0.80 < quality < 0.90 :       463 elements
# Info    : 0.90 < quality < 1.00 :       312 elements
# Info    : 23 edge swaps, 0 node relocations (volume = 152.147): worst = 0.309823 / average = 0.757786 (Wall 0.000409804s, CPU 0.000424s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        34 elements
# Info    : 0.40 < quality < 0.50 :        87 elements
# Info    : 0.50 < quality < 0.60 :       135 elements
# Info    : 0.60 < quality < 0.70 :       280 elements
# Info    : 0.70 < quality < 0.80 :       487 elements
# Info    : 0.80 < quality < 0.90 :       465 elements
# Info    : 0.90 < quality < 1.00 :       311 elements
# Info    : Done optimizing mesh (Wall 0.00358097s, CPU 0.003822s)
# Info    : 845 nodes 5419 elements
# Info    : Writing 'msh_meshes/9_peb.msh'...
# Info    : Done writing 'msh_meshes/9_peb.msh'
# Info    : Writing 'vtk_meshes/9_peb.vtk'...
# Info    : Done writing 'vtk_meshes/9_peb.vtk'
# -------------------------------------------------------
# Version       : 4.11.1
# License       : GNU General Public License
# Build OS      : MacOSX-sdk
# Build date    : 20230730
# Build host    : Mac-1690686203827.local
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack MathEx[contrib] Mesh Metis[contrib] Mpeg Netgen ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : runner
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
