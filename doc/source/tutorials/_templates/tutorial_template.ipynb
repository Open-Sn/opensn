# %% [markdown]
# # [Tutorial title]
#
# [One paragraph explaining the problem and why it matters.]
#
# **Audience:** [Who should use this tutorial?]
#
# **Prerequisites:** [Required tutorials or concepts.]

# %% [markdown]
# ## Learning objectives
#
# By the end of this tutorial, you will be able to:
#
# - [Objective one.]
# - [Objective two.]

# %% [markdown]
# ## Set up the model
#
# [Explain the OpenSn objects used in the next cell.]

# %%
# Add the smallest complete example needed for the learning objectives.

# %% [markdown]
# ## Verify and interpret the result
#
# [State the expected physical or numerical result before checking it.]

# %%
# Assert a stable result and print a key-value pair for tests.json.

# %% [markdown]
# ## Next steps
#
# [Link to the next tutorial and summarize what changes there.]
